# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("history/NoteEmbedding_1211_200624.csv")
plt.plot(df['loss'], label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('NEM Training Loss')
plt.legend()
plt.savefig("img/NEM_train_loss.png", dpi=300)
plt.show()
