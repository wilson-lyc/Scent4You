# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# %%
df = pd.DataFrame(columns=['note','class'])

# %%
path = "html/wikiparfum"
for filename in os.listdir(path):
    if filename.endswith('.html'):
        file_path = os.path.join(path, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            html = f.read()
            
        class_name = filename.replace('.html', '')
        print(f"===== {class_name} =====")
        
        soup = BeautifulSoup(html, 'html.parser')
        items = soup.find_all("div", class_='items-start')
        print(f"Total notes: {len(items)}")
        
        notes_list = []
        for item in items:
            span = item.find("span", class_='break-all sm:break-normal text-16 mb-1 text-black block overflow-hidden text-ellipsis')
            notes_list.append(span.get_text(strip=True))
        print(notes_list)
        
        temp_df = pd.DataFrame({
            'note': notes_list,
            'class': [class_name] * len(notes_list)
        })
        
        df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# ===== 东方调 =====
# Total notes: 56
# ['琥珀', '香草', '零陵香豆', '焚香/乳香', '岩蔷薇/赖白当', '安息香', '没药', '榄香脂', '香草（马达加斯加）', '香草（波旁岛）', '冷杉香脂', '红没药', '香脂（秘鲁）', '香醋香调', '妥鲁香脂', '香豆素（零陵香豆香调）', '安息香（暹罗）', '树脂', '古芸香脂', '苦配巴香脂/古巴香脂', '安息香（老挝）', '焚香（索玛利亚）', '香草（大溪地）', '香草醛（香草香调）', '龙涎香苯乙烯', '安息香（苏门答腊岛）', '香草（墨西哥）', '盐琥珀', '天鹅绒香调', 'Tonkalactone', '香草（香荚兰）', '干琥珀', '柯巴脂', '生橡胶', '龙涎香脂', 'Loewe 香调', '贝鲁树脂', '香醋香调', '草木犀', '海盐香草', 'Kyphi Accord', '格思龙葵骨', '焚香（中国）', 'Ambre 83 de Laire', '香草（塔希提香草兰）', 'Mystikal (Incense note)', 'White Vanilla', 'Invictus Incense', '焚香（摩洛哥）', '香草（乌干达）', '香草利口酒', '印度乳香', 'Blue Vanilla', 'Vanilla Dries Van Noten', 'Invictus Tonka Bean', 'Zukoh']
# ===== 木质香调 =====
# Total notes: 144
# ['檀香', '雪松', '香根草', '木质香调', '乌木/沉香木', '开司米酮（木调麝香）', '愈疮木', '龙涎香型', '降龙涎香醚（龙涎香型）', '干膜莎草/印度香附子', '香根草（海地）', '雪松（弗吉尼亚）', '琥珀木', '雪松（阿特拉斯）', 'Ambrox（龙涎香）', '檀香（澳大利亚）', '纸莎草', '木调琥珀香调', '橡树', '浮木', '阿米香树', '干燥木质', '檀香（印度）', '檀香（迈索尔）', '柚木', '威士忌', '干邑白兰地', '黑檀', '龙涎酮（雪松香调）', '香根草（爪哇岛）', '乌木（老挝）', 'Orcanox（龙涎香）', '雪松（德克萨斯）', '桃花心木', '日本扁柏木', '檀香（新喀里多尼亚）', 'Ambrofix（龙涎香）', '绿檀木', '烟熏树木', '雪松（黎巴嫩）', '香根草（波旁岛）', '红杉', '极致龙涎（木调琥珀香）', '帝王龙涎（木调琥珀香）', '乌木（柬埔寨）', 'Georgywood（雪松香调）', '左旋龙涎醚/龙涎呋喃（龙涎香型）', '雪松（中国）', '橄榄树', '汤力琥珀（木调琥珀香）', '喀什米尔木', '柠檬树', 'Dreamwood (檀香)', 'Ambrostar (木调琥珀香)', 'Pepperwood', '雪松（阿拉斯加）', 'Lorenox（龙涎香）', '白兰地', '檀香（印度尼西亚）', '红檀香', '乌木（罗望子）', 'Norlimbanol（木调琥珀香）', '橘树', '枫树', '雪松（美国）', '香根草（印尼）', 'Ambermax（木调琥珀香）', '雪松（喜马拉雅）', '蓝花楹', '香根草（印度）', '黄杨木', 'Operanide（木调琥珀香）', 'Belambre（木调琥珀香）', '芳香薄荷', '杏树', '苹果树', '异域树木', '铁木（角树）', 'Javanol（檀香）', '湿材', '树皮', '加菲力士（木质香调）', '纸', 'Timbersilk（雪松香调）', '檀香（斯里兰卡）', '樱桃树', 'Ambrinol（龙涎香）', '棉白杨/杨树', '金合欢树', '葡萄柚树', 'Limbanol（木调琥珀香）', '粘土', 'Buaya Laos', 'Karmawood', 'Z11（木调琥珀香）', 'Milkwood', 'Cachalox (Ambergris)', '林木（木质音符）', '佛陀木', '圣诞树/凤凰木', '美国梧桐', 'Kingwood', 'Queenwood', '烧焦香调', 'Karanal（木调琥珀香）', 'Santamanol（檀香）', '香根草（留尼旺岛）', '疗伤木（广藿香味）', 'Sandalore （檀香）', '李子树', '白柳树', '树木（巴西）', '核桃木', 'Timberol（雪松香调）', 'Ebanol（檀香）', 'Dextramber® (Woody Ambery)', '山毛榉', '梨树', '柳条', '银杏', '雪松（秘鲁）', '罗汉柏', '檀香（埃及）', 'Tobacarol（木质琥珀）', 'Cedramber（雪松香调）', 'Vinyl Guaiacol', '乌木（印度）', '米蒂花油', '乌木（泰国）', '马卡萨木', 'Okoumal（木调琥珀香）', '涂蜡地板香调', '檀香（马达加斯加）', '梦迪亚根', '三叶胶', '雪松（西藏）', 'Bacdanol（檀香）', '假紫荆', '木兰花木', 'Vertofix Coeur （雪松香调）', 'Invictus Opulent Wood', 'Mizunara Wood (Japanese Oak)', 'Shiba-Fune Wood', 'Hindinol® (Sandalwood)']
# ===== 果香调 =====
# Total notes: 141
# ['桃子', '梨', '覆盆子', '苹果', '李子', '菠萝', '黑加仑', '红莓', '椰子', '荔枝', '绿苹果', '大黄', '杏', '无花果', '朗姆酒', '草莓', '印蒿', '果香调', '百香果', '甜瓜', '椰奶', '黑莓', '芒果', '金盏花', '樱桃', '西瓜', '石榴', '红苹果', '野莓', '红醋栗', '油桃', '蓝莓', '柑橘', '干果', '番石榴', '枣', '樱桃（黑色）', '香槟', '葡萄', '杨桃', '蔓越莓', '猕猴桃', '异域水果', '水润水果', '黄香李（李子）', '梨味雪芭', '利口酒', '木瓜', '鸡尾酒', '内酯酸香调（水果牛奶）', '火龙果', '粉红香槟', '红葡萄酒', '蜜瓜', '热带水果', '香蕉', '酸角', '毕当茄', '露莓', '阿萨伊莓果/巴西莓', '博伊森莓', '酸樱桃', '醋栗', '仙人果', '枸杞', '苹果雪芭', '黑加仑雪芭', '覆盆子雪芭', '石榴汁糖浆', '桑葚', '白醋栗', '云莓', '南非红茶', '椰林飘香鸡尾酒', '雪芭', '贝利尼鸡尾酒', '山竹', '欧洲樱桃', '黑樱桃', 'Dewfruit（异域水果）', '麝香葡萄', '梅酒', '嘉宝果', '柿子', '马尼卡', 'Cosmofruit（水果香调）', '苹果酒', '绿色水果', '树莓利口酒', '酒浸樱桃', '普罗塞克', '阿贝罗鸡尾酒', '波特酒', '桃子雪芭', '果酒', '瓜拿纳', '菠萝蜜', '果酱', '甜瓜（刺角瓜）', 'Prunella（李子）', '草莓雪芭', '葡萄酒糟', '酸浆果', 'Prunol（李子）', '日本枇杷', '乙酸乙酯（水果香调）', 'Paradisamide（水果香调）', '牙买加人心果', '黑皮诺葡萄', '能量饮料香调', '刺果番荔枝', 'Antillone（水果香调）', '番荔枝树', '斐济果', '荔枝雪芭', 'Veloutone（水果香调）', '葡桃', '橙味利口酒', 'Creamytone (果香调)', '糖霜莓果', '蜜瓜香调', '葡萄覆盆子冰糕', '玛格丽特鸡尾酒', '水果茶', '菠萝莓', '香波堡利口酒', '酸枣', '月桂果实', 'Miracle berry', '星苹果', '白葡萄酒', '桑格利亚酒', '格拉巴酒', '覆盆子莫吉托', '桑橙', '樱桃棒棒糖香调', 'Malibu椰子酒', '樱桃牛奶谐香', 'Winter berry', 'Durian', 'Fig of Egypt (Carob tree)']
# ===== 柑橘调 =====
# Total notes: 76
# ['香柠檬', '橘子', '柠檬', '葡萄柚', '甜橙', '橙花油', '柑橘', '橘子', '青柠', '苦橙', '血橙', '柠檬马鞭草', '柚子', '柑橘（绿色）', '香橼', '柠檬皮', '细皮小柑橘', '金橘', '柚子', '柠檬花', '柠檬草', '山苍树', '橘子花', '柑橘（红色）', '橙花（突尼斯）', '柑橘（西西里）', '莫吉托', '葡萄柚花', '卡菲尔酸橙（泰国柠檬）', '柠檬雪芭', '鱼子青柠', '金汤力', 'Dihydromyrcenol（清新柑橘香）', '柠檬马鞭草', '凯匹林纳鸡尾酒', '柑橘（糖渍）', '加利蒙地亚橘', '香茅', '香蜂草', '柠檬汤力水', 'Pamplewood（葡萄柚香调）', 'Lemon (Italia)', '柠檬甜酒', 'Lemon (Sicilia)', '橙子（巴伦西亚）', '青柠（波斯）', '香柠檬花', '金巴利苦酒', '柠檬汽水', '佛手', '葡萄柚（中国）', '圣培露果汁', '柑橘', '柑橘（中国）', '柑橘雪芭', '活力香调', '橙子（塔洛科）', '德岛酸橘', '古龙香调', '柑桔花', 'Neroli (Moroccan)', '柠檬奶油（凝乳）', '佛手柑雪芭', '柑香酒', '圆柚甲烷（葡萄柚香调）', '酸味香调', '橙子（摩洛哥）', '橙花（卡拉布里亚）', '莱姆金桔', 'Grapefruit Dries Van Noten', '柠檬百里香', '皮斯科酸味鸡尾酒', '柑橘青柠香调', '茶（葡萄柚）', '橘树和柠檬树花', '橙子（巴西 Pintango）']
# ===== 柑苔香调 =====
# Total notes: 18
# ['广藿香', '橡木苔', '苔藓', '广藿香（印度尼西亚）', '亚基戛纳木 (广藿香调)', '土壤香调', '千龙木（广麝香香调）', '柑苔谐香', '太妃糖', 'Evernyl（青苔）', '蘑菇', '白松露', '甜菜根', '干叶', '森林土地', '泥炭', '土壤香调', '广藿香（危地马拉）']
# ===== 概念性 =====
# Total notes: 34
# ['矿物质香调', '沙子香调', '墨水', '石头', '乙烯基', '防滑蜡', '鹅卵石', '火石', '清漆香调', '肾上腺素香调', 'Filo di Seta香调', '沥青', '汽油', '鲜血香调', '碳香调', '蒸汽', '水泥', '彩虹香调', '分子（粉色）', '银质香调', 'Electric Mist', '粉笔', '石灰岩', '榻榻米', '乙醚', '胶片香调', 'On The Rocks Accord', '工业胶水', 'Black Lacquer accord', '石膏', '可卡因香调', '铂金香调', '煤油', '真丝香调']
# ===== 海洋调 =====
# Total notes: 27
# ['海洋', '海洋调', '臭氧香调', '海水', '海草/海藻', '咸香', '海风', '西瓜酮（海洋清香）', '露珠', '雨水香调', '高山空气', '冰块效应', '海风醛（海洋清香）', '汤力水', '雪花香调', '鱼子酱', '碘香调', 'Aquozone（海洋清香）', 'Helional（海洋调）', '沙漠空气香调', '地中海空气香调', '圣彼得草', 'Head Space 瀑布', 'Calypsone（海洋清香）', '晶体协议', 'Transluzone（海洋清香）', 'Oceanol（海洋清香）']
# ===== 烟草香调 =====
# Total notes: 7
# ['烟草叶', '干草', '烟草香调', '烟草花', '鹿舌草', '水烟筒香调', '灰烬']
# ===== 皮革香调 =====
# Total notes: 22
# ['皮革', '藏红花', '麂皮', '安息香', '桦木', '海狸香', '灵猫香', '动物香调', '烟雾', '杜松', '桦焦油', '正山小种红茶', '闭鞘姜', '火药', 'Safraleine（藏红花香）', '蹄兔香', 'Civetone（动物香调）', '火焰能量', '熔岩', 'Suederal（麂皮香调）', '俄罗斯茶', '小羊皮']
# ===== 美食香调 =====
# Total notes: 110
# ['焦糖', '蜂蜜', '杏仁', '果仁糖', '咖啡', '可可', '糖', '奶油（奶油泡芙）', '甘草', '牛奶', '榛子', '巧克力', '棉花糖', '开心果', '棉花糖', '大米', '红糖', '太妃糖', '美食香调', '蜂蜡', '杏仁奶', '栗子', '芝麻', '黑巧克力', '核桃', '甘蔗', '太妃苹果糖', '麦芽醇（果仁糖）', '白巧克力', '糖果', '枫糖浆', '糖衣杏仁', '海盐焦糖', '卡布奇诺咖啡', '马卡龙', '姜饼', '杏仁酒', '烤杏仁', '热牛奶', '黄油', '谷类', '法式甜點', '爆米花', '蛋白糖', '蜜饯', '牛奶焦糖酱', '冰淇淋', '小麦', '咖啡（阿拉比卡）', '焦糖布丁', '杏仁糕', '可口可乐', '泡泡糖', '饼干', '提拉米苏香调', '大麦', '纸杯蛋糕', '土耳其软糖', '夏威夷果', '麸', '可可脂', '麦芽', '糖渍橙子', '奶油苏打', '玛德琳蛋糕香调', '牛奶巧克力', '牛奶慕斯', '牛轧糖', '糖渍栗子', '炼乳', '面粉（蛋糕）', '面包', '意式奶冻', '南瓜', '苦巧克力', '曲奇香调', '花粉', '巧克力（吉安杜佳）', '奶油硬糖', '花生', '米浆', '拿铁咖啡', '布里欧修面包//法式黄油面包', '蛋奶冻', '奶油乳酪', '哈尔瓦蜜糕', '黑麦', '咖啡（土耳其）', '咖啡（哥伦比亚）', '蒂拉米松', '啤酒', '芝士', '可露丽香调', '鹰嘴豆', '烘烤香调', '腰果', '百利甜酒', '葡萄醋', '印度冰淇淋', '蜂蜜酒', '布雷谢', '糯米团', '可乐果', '烤乳木果', '冰冻酸奶的乐趣', '小豆子', '咖啡酒类', '软糖', 'Buckwheat Accord', 'Walnut Milk']
# ===== 花香调 =====
# Total notes: 296
# ['茉莉', '玫瑰', '橙花', '鸢尾花', '紫罗兰', '铃兰', '依兰', '小苍兰', '牡丹', '晚香玉', '木兰', '茉莉（阿拉伯茉莉）', '天芥菜', '栀子花', '玫瑰（土耳其）', '花香调', '玫瑰（保加利亚）', '桂花', '百合', '兰花', '金合欢', '莲花', '康乃馨', '仙客来', '睡莲', '黑檀红木', '玫瑰（格拉斯）', '鸡蛋花', '金银花', '千叶玫瑰', '大马士革玫瑰', '茉莉（埃及）', '蒂亚蕾花', '紫丁香', '白色花卉', '风信子', '水仙', '脂粉香调', '茶', '阳光香调', '红茶', '樱花', '希蒂莺（淡雅茉莉香）', '胡萝卜籽', '鸢尾花（佛罗伦萨/托斯卡纳）', '桃花', '玫瑰花瓣', '苹果花', '茉莉（印度）', '白茶', '山楂', '玫瑰（摩洛哥）', '茉莉（格拉斯）', '茉莉（虎头兰）', '木槿', '杏花', '棉花', '金雀花', '菩提花', '水仙花', '紫藤', '香豌豆', '夜茉莉', '西番莲', '梨花', '橙花（突尼斯）', '玫瑰（塔伊夫）', '犬蔷薇', '黄兰花', '依兰（马达加斯加）', '罂粟花', '橙花（摩洛哥）', '金合欢树', '水杨酸盐（花香调）', '山茶花', '鸢尾花（帕丽达）', '曼陀罗', '茉莉（摩洛哥）', '山梅花', '玫瑰花茶', '郁金香', '茉莉花茶', 'Heliotropine（天芥菜）', '姜花', '沼泽革木', '桂花（中国）', '李子花', '雏菊', '海桐花', 'Paradisone（淡雅茉莉香）', 'Mahonial (铃兰)', 'Pomarose（葡桃香调）', '亚麻', '姜百合', '茉莉（阿拉伯）', '玫瑰草', '夜香树', 'Petalia（玫瑰花瓣）', '决明子', '合欢花', '大丽花', '野花', '黑接骨木', '龙胆根', '伯爵红茶', '锡兰红茶', '凤眼兰', '风铃草', '孤挺花', '杏花', '向日葵', '紫茉莉', '木兰花（中国）', '铃兰', '树莓花', '口红', '千金子藤', '黑莓花', '帕塔奎拉花', '异域花香调', '鸢尾花（摩洛哥）', '玫瑰（印度）', '木樨草', '玫瑰', '咖啡花', '玫瑰果', '云南红茶', '波罗尼亚花', '雪绒花', '雪花莲', '桂竹香', '可可花', '茉莉（意大利）', '花香调', '菊花', '石竹', '绣球花', '夹竹桃', '月光花', '使君子', 'Hivernal（铃兰）', '荆豆', '苦艾蒿', '茉莉（印度尼西亚）', '依兰（马约特岛）', '百合花 (Lily Of The Valley)', '卡罗花', '帕米拉花', '黑加仑花', '茉莉（中国）', '十大功劳', '含羞草（格拉斯）', '玫瑰（英国产地）', '颠茄', '醉鱼草', '瑞香', '石榴花', '芒果花', '五月花', '橄榄花', '金盏花', '香蕉花', '苋菜', '亚麻', '芳樟树/香樟树', '茉莉花', '繁缕花', 'Lisylang（依兰）', '蓼', '杜鹃花', '锦葵', '清酒', '玫瑰（埃及）', '中国红茶', '芳樟醇（花香调）', '不死草', '蓝罂粟', '花毛茛', '蒲公英', '沙漠玫瑰', '吲哚（动物花香）', '麦努卡蜂蜜', '报春花', '缎木', '蓍草', '薄荷油', '玫瑰（中国）', '匙叶草', '水润铃兰（铃兰）', '风铃花', '矢车菊，Sultan Seeds', '文珠兰', '勿忘我', '马缨丹', '木瓜花', '女贞木', '紫罗兰花', '剑兰', '紫罗兰（非洲）', '冬青树', '九重葛', '夏蜡梅', '巧克力花', '倒挂金钟', '黑种草', '鸦片', '三色堇', '圣约翰草', '杜鹃花', '大波斯菊', '毛地黄', '热带花卉', '天堂鸟', '鸢尾花（中国）', '无忧花', 'Nympheal（铃兰）', '白鹤芋', 'Damascenone （苹果玫瑰香调）', '马蹄莲', '木樨草', '夹竹桃', '石榴花', '沙漠棕榈花', '琉璃苣花', '番红花', '玫瑰（意大利）', '阿萨姆红茶', '海水仙花', '银莲花', '炮弹花', '球兰', '玻璃翠', '流血的心脏花', '吴茱萸', '羽扇豆', 'Nerolex', '长春花', '含笑花', '荷荷巴油', '干花', '森林花朵', '茉莉（卡拉布里亚）', '果冻（玫瑰）', 'Lilial（铃兰）', '含羞草（印度）', '赤陶', '茉莉（秘鲁）', '牵牛花', 'Ebelia分子', 'Kharismal（淡茉莉）', '葡萄花', '玫瑰利口酒', 'Starfleur（铃兰）', 'Yodanol (花香)', '巴西木花', 'Moraea ciliata', '黑加仑花', '假虎刺', '蜡梅/腊梅', '秋麒麟草', '藜芦花', '透纳树叶', '白日草', '花', 'Flora Mortis 香调', '山茶', '木绣球', '巴库拉花', '乙酸苄酯（茉莉）', '红缎花', '紫草', 'Cyclosal（铃兰）', '卡哈亚', '玫瑰水', '缅甸茶', '玫瑰（京都）', '玫瑰（班加罗尔）', 'Nightscent Mathiola', '山玉兰', 'Givescone（葡桃香调）', '芸香', '紫锥花', '乙酸乙醛乙基芳樟', 'Irotyl（鸢尾花）', '芳香玫瑰醚（玫瑰）', '牛舌草', '海棠花', '海神花', '辣木', '喜马拉雅轮生花', '白玉草', '天堂莲花', 'Jasmodione®', 'Rose Dries Van Noten', 'Iris Dries Van Noten', 'Cherry Peony']
# ===== 辛香调 =====
# Total notes: 59
# ['小豆蔻', '粉红胡椒', '肉桂', '姜', '肉豆蔻', '黑胡椒', '丁香', '芫荽', '杜松子', '胡椒', '香料香调', '莳萝', '当归', '永久花', '四川辣椒', '胡椒', '白胡椒', '月桂', '辣椒', '葛缕子', '肉桂叶', '胡椒（马达加斯加）', '姜黄粉', '辣椒', '热香料', '青椒', '清新香料', '红姜', '芹菜籽', '甜椒', '姜（马达加斯加）', '葫芦巴', '肉豆蔻仁', '丁香叶', '瑞卡草', '姜（印度）', '红辣椒', '人参', '甜椒叶', '胡椒（秘鲁）', '印度拉茶', '胡椒叶', '姜（中国）', '苦香皮', '胡椒（牙买加）', 'Ishpink', '姜（尼日利亚）', '咖喱树', '漆树', '姜（牙买加）', '印度香料', '胡椒（墨西哥辣椒）', '多香果', '摩洛哥香料', '酸辣酱', '姜（日本）', 'Forest Pepper Jungle Essence', '胡椒（波斯）', '玄米茶香调']
# ===== 醛香调 =====
# Total notes: 11
# ['醛', '金属香调', '清爽香调', '香皂香调', '白T恤香调', 'CristalFizz', 'Sclarene', '干冰（乙醛）', '合成香调', 'Presantone H（乙醛）', 'Adoxal（醛）']
# ===== 青香调 =====
# Total notes: 113
# ['黑加仑芽', '紫罗兰叶', '苦橙叶', '绿叶香调', '白松香', '树叶', '绿茶', '马黛茶', '无花果叶', '竹子', '新割青草', '常春藤', '乳香树', '草本植物', '黄瓜', '番茄叶', '胡萝卜', '仙人掌', '黑加仑叶', '苦橙叶', '植物汁液', '蕨', '紫苏叶', '无花果树', '三叶草', '树莓叶', '无花果奶', '柑橘叶', '桦树叶', '玫瑰醚', '菠萝叶', '花茎', '绿柑橘', '抹茶', '绿色海洋香调', '库拉索芦荟', '绿叶', '棕榈叶', '木兰叶', '菖蒲', '龙舌兰', '甘松香', '柑橘叶', '乌龙茶', '草莓叶', '藤蔓', '香蕉叶', '梨树叶', '荨麻', '芦苇', '西红柿', '橄榄叶', '大吉岭红茶', '青柠叶', '玫瑰刺', '芥末', '黑莓叶', '杨树芽', '绿色热带香调', '榛子叶', '李子叶', '古柯叶', '鸢尾花叶', '啤酒花', '佛手柑叶', '刺山柑', '含羞草叶', '黄花草', '栀子花叶', 'Mugweed', '西洋菜', '滨草（沙滩草）', '缬草', '金合欢叶', '辣椒叶', '毛豆', '灌木', '无花果叶', '茉莉叶', '豌豆', '苹果叶', '杏叶', '莴苣', '旱金莲花', '可可叶', '玉米', '角豆树', '双环芳烃（青香调）', '牛油果', '阿米芹', '马缨丹叶', '大豆', '艾菊', '水飞蓟', '绿辣椒', '萝卜', '三齿拉雷亚灌木', '豆子（广义）', '亚油酸乙酯', '槟榔叶', 'Violettyne（紫罗兰叶）', '桂花叶', 'Kogomi 叶', '乙酸苏合香酯（绿叶香调）', '乙酸己酯', '榆叶', '氧化苯基', '女贞醛（绿叶香调）', '花椰菜', 'Humus Ether® (Earthy Note)', 'Rose Oxide, L-cis', 'Galbanum Dries Van Noten', 'Veridian (Violet leaves)']
# ===== 馥奇调 =====
# Total notes: 80
# ['薰衣草', '天竺葵', '快乐鼠尾草', '薄荷', '迷迭香', '罗勒', '柏树', '百里香', '蒿', '松针', '杂薰衣草', '茴香', '八角', '洋甘菊', '芳香香调', '桉树', '龙嵩叶', '绿薄荷', '胡椒薄荷', '天竺葵（埃及）', '雪松叶', '苦艾酒', '桃金娘', '薰衣草（普罗旺斯）', '苦艾', '月桂树', '大麻香调', '冷杉', '茴香籽', '牛至', '馥奇香调', '杜松子酒', '合香叶/布枯', '马郁兰', '樟脑', '冻薄荷', '伏特加', '云杉', '薰衣草（英国）', '海索草', '欧石楠', '橄榄', '北美山艾树', '天竺葵（中国）', '龙舌兰酒', '薄荷（摩洛哥）', '罗勒（埃及）', '黑云杉', '欧芹', '莳萝', '薄荷茶', '冰镇伏特加', '铁杉', '茶树油', '橄榄油', '金钟柏', '罗勒（泰国）', '罗勒（越南）', '海茴香', '苦艾酒', '薄荷脑', '桉树（中国）', '冷杉（西伯利亚蓝色）', '罗勒花', '普罗旺斯香料', '柠檬薄荷', '凤仙花', '薰衣草（尼翁）', '桉树（澳大利亚）', '零陵香（圣罗勒）', '松脂', '环丙基茴香醚', '马天尼', '香罗勒', 'menthyl acetate（薄荷）', '野格炸弹鸡尾酒', '麦斯卡尔酒', '薰衣草（塞维利亚）', '茴香花', '罗勒（印尼）']
# ===== 麝香调 =====
# Total notes: 32
# ['麝香', '黄葵', '肌肤香调', 'Muscone（麝香）', 'Sylkolide（麝香）', 'Helvetolide（麝香）', '信息素', 'Muscenone（麝香）', 'Sinfonide（麝香）', '麝香', 'Cosmone（麝香）', 'Nirvanolide（麝香）', '葵子麝香', 'Serenolide（麝香）', 'Habanolide（麝香）', 'Galaxolide（麝香）', '性感谐香', 'Vulcanolide（麝香）', 'Globalide (麝香)', 'Exaltolide（麝香）', '山梨醇内酯（麝香）', '罗曼麝香（麝香）', 'Silvanone（麝香）', '羊毛', 'Ambrexolide（麝香）', '尼布龙（麝香）', 'Moxalone（麝香）', 'Tonalide（麝香）', 'Astrotone（麝香）', '大环麝香（麝香）', 'Edenolide （麝香）', 'L-Muscone (Musk)']

# %%
# Save
df.to_csv("data/note_type.csv", index=False)
